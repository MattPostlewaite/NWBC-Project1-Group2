# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/Crimes_-_2015.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

crimes_2015 = df[["Primary Type", "Description","Latitude","Longitude"]]
crimes_2015 = crimes_2015.dropna()
crimes_2015.to_csv('crimes_2015_clean.csv',encoding='utf-8')
crimes_2015
# Out:
#                    Primary Type  \
# 0                       BATTERY
# 1                         THEFT
# 2                     NARCOTICS
# 3                       ASSAULT
# 4                      BURGLARY
# ...                         ...
# 264610            OTHER OFFENSE
# 264611                  BATTERY
# 264612                  BATTERY
# 264613                  BATTERY
# 264616  CRIMINAL SEXUAL ASSAULT
#
#                                               Description   Latitude  \
# 0                                 DOMESTIC BATTERY SIMPLE  41.815117
# 1                                          POCKET-PICKING  41.895080
# 2                                   POSS: HEROIN(BRN/TAN)  41.937406
# 3                                                  SIMPLE  41.881903
# 4                                          FORCIBLE ENTRY  41.744379
# ...                                                   ...        ...
# 264610                              OTHER VEHICLE OFFENSE  41.910395
# ...

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/Crimes_-_2011.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

crimes_2011 = df[["Primary Type", "Description","Latitude","Longitude"]]
crimes_2011 = crimes_2011.dropna()
crimes_2011.to_csv('crimes_2021_clean.csv',encoding='utf-8')
crimes_2011
# Out:
#                       Primary Type  \
# 0               DECEPTIVE PRACTICE
# 3               DECEPTIVE PRACTICE
# 4               DECEPTIVE PRACTICE
# 6               DECEPTIVE PRACTICE
# 7               DECEPTIVE PRACTICE
# ...                            ...
# 351926                     BATTERY
# 351929                     ASSAULT
# 351930  OFFENSE INVOLVING CHILDREN
# 351931               OTHER OFFENSE
# 351932                     BATTERY
#
#                                               Description   Latitude  \
# 0                     FINANCIAL IDENTITY THEFT OVER $ 300  41.747362
# 3                     FINANCIAL IDENTITY THEFT OVER $ 300  41.891766
# 4                     FINANCIAL IDENTITY THEFT OVER $ 300  41.895419
# 6                     FINANCIAL IDENTITY THEFT OVER $ 300  41.875944
# 7                     FINANCIAL IDENTITY THEFT OVER $ 300  41.987282
# ...                                                   ...        ...
# ...

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/Crimes_-_2021.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

crimes_2021 = df[["Primary Type", "Description","Latitude","Longitude"]]
crimes_2021 = crimes_2021.dropna()
crimes_2021.to_csv('crimes_2021_clean.csv',encoding='utf-8')
crimes_2021
