# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import api_key

# %%
csv_path_1 = os.path.join("chi_school_2011_2012.csv")
schools_2011_df = pd.read_csv(csv_path_1, encoding="utf-8")
schools_2011_df.head()
# Out:
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# 3     60651  (773) 534-4290
# ...

# %%
#schools_2011_df.columns

# %%
schools_2011_df = schools_2011_df[['School ID','Name of School','ZIP Code','Elementary, Middle, or High School','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2011_df["Year"] = "2011"
schools_2011_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 0       609966               Charles G Hammond Elementary School     60623
# 1       610539                   Marvin Camras Elementary School     60634
# 2       609852                  Eliza Chappell Elementary School     60625
# 3       609835                Daniel R Cameron Elementary School     60651
# 4       610521         Sir Miles Davis Magnet Elementary Academy     60636
# ..         ...                                               ...       ...
# 561     610506      TEAM Englewood Community Academy High School     60621
# 562     610350           Robert A Black Magnet Elementary School     60619
# 563     610154                Martin A Ryerson Elementary School     60624
# 564     610384  Infinity Math Science and Technology High School     60623
# 565     609870                Daniel J Corkery Elementary School     60623
#
#     Elementary, Middle, or High School Graduation Rate %  Ward  \
# ...

# %%
schools_2011_df = schools_2011_df[schools_2011_df['Elementary, Middle, or High School'] == "HS"]
schools_2011_df = schools_2011_df[['School ID','Name of School','ZIP Code','Graduation Rate %', 'Ward','Average Student Attendance','Year']]
schools_2011_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 8       609680     Walter Payton College Preparatory High School     60610
# 15      609722                 Manley Career Academy High School     60612
# 17      609749         Northside College Preparatory High School     60625
# 28      610244    Michele Clark Academic Prep Magnet High School     60644
# 30      610394                      Uplift Community High School     60640
# ..         ...                                               ...       ...
# 554     609753     Chicago High School for Agricultural Sciences     60655
# 559     609724                      Stephen T Mather High School     60659
# 560     610297          High School of Leadership at South Shore     60649
# 561     610506      TEAM Englewood Community Academy High School     60621
# 564     610384  Infinity Math Science and Technology High School     60623
#
#     Graduation Rate %  Ward  Average Student Attendance  Year
# ...

# %%
csv_path_2 = os.path.join("chi_school_2015_2016.csv")
schools_2015_df = pd.read_csv(csv_path_2, encoding="utf-8")
schools_2015_df.head()
# Out:
#    School_ID           Short_Name  \
# 0     610547  SOUTH SHORE INTL HS
# 1     400097     NOBLE - BULLS HS
# 2     610515         DISNEY II ES
# 3     609997               HOLMES
# 4     609678             JONES HS
#
#                                        Long_Name           School_Type  \
# 0      South Shore Intl College Prep High School  Selective enrollment
# 1             Noble - Chicago Bulls College Prep               Charter
# 2                        Disney II Magnet School                Magnet
# 3        Oliver Wendell Holmes Elementary School          Neighborhood
# 4  William Jones College Preparatory High School  Selective enrollment
#
#   Primary_Category              Address     City     State    Zip  \
# 0               HS       1955 E 75TH ST  Chicago  Illinois  60649
# 1               HS      2040 W ADAMS ST  Chicago  Illinois  60612
# 2               ES   3815 N KEDVALE AVE  Chicago  Illinois  60641
# ...

# %%
schools_2015_df.columns
# Out:
# Index(['School_ID', 'Short_Name', 'Long_Name', 'School_Type',
#        'Primary_Category', 'Address', 'City', 'State', 'Zip', 'Phone',
#        ...
#        'Mobility_Rate_Pct', 'Chronic_Truancy_Pct',
#        'Empty_Progress_Report_Message', 'School_Survey_Rating_Description',
#        'Supportive_School_Award', 'Supportive_School_Award_Desc',
#        'Parent_Survey_Results_Year', 'School_Latitude', 'School_Longitude',
#        'Location'],
#       dtype='object', length=153)

# %%
schools_2015_df = schools_2015_df[['School_ID','Short_Name','Zip','Primary_Category','Student_Attendance_Avg_Pct','College_Enrollment_School_Pct_Year_2']]
schools_2015_df["Year"] = '2015'
schools_2015_df
# Out:
#      School_ID           Short_Name    Zip Primary_Category  \
# 0       610547  SOUTH SHORE INTL HS  60649               HS
# 1       400097     NOBLE - BULLS HS  60612               HS
# 2       610515         DISNEY II ES  60641               ES
# 3       609997               HOLMES  60621               ES
# 4       609678             JONES HS  60605               HS
# ..         ...                  ...    ...              ...
# 665     610173             SHERWOOD  60621               ES
# 666     610115           PARK MANOR  60637               ES
# 667     609996               HOLDEN  60608               ES
# 668     609815              BOUCHET  60649               ES
# 669     400135  YCCS - LATINO YOUTH  60608               HS
#
#      Student_Attendance_Avg_Pct  College_Enrollment_School_Pct_Year_2  Year
# 0                          88.8                                   NaN  2015
# 1                          88.8                                  83.2  2015
# ...

# %%
schools_2015_df = schools_2015_df[schools_2015_df['Primary_Category'] == "HS"]
schools_2015_df = schools_2015_df[['School_ID','Short_Name','Zip','Primary_Category','Year','Student_Attendance_Avg_Pct','College_Enrollment_School_Pct_Year_2']]
schools_2015_df
# Out:
#      School_ID                     Short_Name    Zip Primary_Category  Year  \
# 0       610547            SOUTH SHORE INTL HS  60649               HS  2015
# 1       400097               NOBLE - BULLS HS  60612               HS  2015
# 4       609678                       JONES HS  60605               HS  2015
# 5       400136            YCCS - OLIVE HARVEY  60628               HS  2015
# 9       610513                   AIR FORCE HS  60609               HS  2015
# ..         ...                            ...    ...              ...   ...
# 645     400124                YCCS - MCKINLEY  60616               HS  2015
# 646     400148          INSTITUTO - LOZANO HS  60608               HS  2015
# 652     400164  INSTITUTO - LOZANO MASTERY HS  60608               HS  2015
# 657     610570           OMBUDSMAN - SOUTH HS  60636               HS  2015
# 669     400135            YCCS - LATINO YOUTH  60608               HS  2015
#
# ...

# %%
csv_path_3 = os.path.join("chi_school_2018_2019.csv")
schools_2018_df = pd.read_csv(csv_path_3, encoding="utf-8")
schools_2018_df.head()
# Out:
#    School_ID Short_Name                                    Long_Name  \
# 0     609710  HARLAN HS  John M Harlan Community Academy High School
# 1     610059      MAYER                    Oscar Mayer Magnet School
# 2     610334    RABY HS                          Al Raby High School
# 3     610237  BEETHOVEN       Ludwig Van Beethoven Elementary School
# 4     610158      SAYRE  Harriet E Sayre Elementary Language Academy
#
#     School_Type Primary_Category              Address     City     State  \
# 0  Neighborhood               HS  9652 S MICHIGAN AVE  Chicago  Illinois
# 1        Magnet               ES   2250 N CLIFTON AVE  Chicago  Illinois
# 2         Small               HS   3545 W FULTON BLVD  Chicago  Illinois
# 3  Neighborhood               ES         25 W 47TH ST  Chicago  Illinois
# 4  Neighborhood               ES   1850 N NEWLAND AVE  Chicago  Illinois
#
#      Zip         Phone  ...  Attainment_SAT_Grade_11_School_Pct  \
# ...

# %%
schools_2018_df = schools_2018_df[['School_ID','Short_Name','Zip','Primary_Category','Student_Attendance_Avg_Pct','College_Enrollment_School_Pct_Year_2']]
schools_2018_df = schools_2018_df[schools_2018_df['Primary_Category'] == "HS"]
schools_2018_df["Year"] = '2018'
schools_2018_df = schools_2018_df[['School_ID','Short_Name','Zip','Primary_Category','Year','Student_Attendance_Avg_Pct','College_Enrollment_School_Pct_Year_2']]
schools_2018_df
# Out:
#      School_ID                     Short_Name    Zip Primary_Category  Year  \
# 0       609710                      HARLAN HS  60628               HS  2018
# 2       610334                        RABY HS  60624               HS  2018
# 9       609712                      HIRSCH HS  60619               HS  2018
# 10      610543                     SOLORIO HS  60632               HS  2018
# 17      610389                         ORR HS  60624               HS  2018
# ..         ...                            ...    ...              ...   ...
# 618     610383              SOCIAL JUSTICE HS  60623               HS  2018
# 621     400142                 YCCS - VIRTUAL  60612               HS  2018
# 625     609723                    MARSHALL HS  60624               HS  2018
# 628     400136            YCCS - OLIVE HARVEY  60628               HS  2018
# 647     400129  YCCS - PROGRESSIVE LEADERSHIP  60637               HS  2018
#
# ...
