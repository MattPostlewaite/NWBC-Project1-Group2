# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/cr/wm661_8s4rnddy4mgjplwkl00000gn/T/ipykernel_12945/2231195172.py in <module>
#       8
#       9 # Import API key
# ---> 10 from api_keys import g_key
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
csv_path_1 = os.path.join("chi_school_2011_2012.csv")
schools_2011_df = pd.read_csv(csv_path_1, encoding="utf-8")
schools_2011_df.head()
# Out:
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# 3     60651  (773) 534-4290
# ...

# %%
#schools_2011_df.columns

# %%
schools_2011_df = schools_2011_df[['School ID','Name of School','ZIP Code','Elementary, Middle, or High School','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2011_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 0       609966               Charles G Hammond Elementary School     60623
# 1       610539                   Marvin Camras Elementary School     60634
# 2       609852                  Eliza Chappell Elementary School     60625
# 3       609835                Daniel R Cameron Elementary School     60651
# 4       610521         Sir Miles Davis Magnet Elementary Academy     60636
# ..         ...                                               ...       ...
# 561     610506      TEAM Englewood Community Academy High School     60621
# 562     610350           Robert A Black Magnet Elementary School     60619
# 563     610154                Martin A Ryerson Elementary School     60624
# 564     610384  Infinity Math Science and Technology High School     60623
# 565     609870                Daniel J Corkery Elementary School     60623
#
#     Elementary, Middle, or High School Graduation Rate %  Ward  \
# ...

# %%
schools_2011_df = schools_2011_df[schools_2011_df['Elementary, Middle, or High School'] == "HS"]
schools_2011_df = schools_2011_df[['School ID','Name of School','ZIP Code','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2011_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 8       609680     Walter Payton College Preparatory High School     60610
# 15      609722                 Manley Career Academy High School     60612
# 17      609749         Northside College Preparatory High School     60625
# 28      610244    Michele Clark Academic Prep Magnet High School     60644
# 30      610394                      Uplift Community High School     60640
# ..         ...                                               ...       ...
# 554     609753     Chicago High School for Agricultural Sciences     60655
# 559     609724                      Stephen T Mather High School     60659
# 560     610297          High School of Leadership at South Shore     60649
# 561     610506      TEAM Englewood Community Academy High School     60621
# 564     610384  Infinity Math Science and Technology High School     60623
#
#     Graduation Rate %  Ward  Average Student Attendance
# ...

# %%
csv_path_2 = os.path.join("chi_school_2015_2016.csv")
schools_2015_df = pd.read_csv(csv_path_1, encoding="utf-8")
schools_2015_df.head()
# Out:
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# 3     60651  (773) 534-4290
# ...

# %%
schools_2015_df = schools_2015_df[['School ID','Name of School','ZIP Code','Elementary, Middle, or High School','Graduation Rate %', 'Ward','Average Student Attendance']]

# %%
schools_2015_df = schools_2015_df[schools_2015_df['Elementary, Middle, or High School'] == "HS"]
schools_2015_df = schools_2015_df[['School ID','Name of School','ZIP Code','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2015_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 8       609680     Walter Payton College Preparatory High School     60610
# 15      609722                 Manley Career Academy High School     60612
# 17      609749         Northside College Preparatory High School     60625
# 28      610244    Michele Clark Academic Prep Magnet High School     60644
# 30      610394                      Uplift Community High School     60640
# ..         ...                                               ...       ...
# 554     609753     Chicago High School for Agricultural Sciences     60655
# 559     609724                      Stephen T Mather High School     60659
# 560     610297          High School of Leadership at South Shore     60649
# 561     610506      TEAM Englewood Community Academy High School     60621
# 564     610384  Infinity Math Science and Technology High School     60623
#
#     Graduation Rate %  Ward  Average Student Attendance
# ...

# %%
csv_path_3 = os.path.join("chi_school_2020_2021.csv")
schools_2020_df = pd.read_csv(csv_path_1, encoding="utf-8")
schools_2020_df.head()
# Out:
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# 3     60651  (773) 534-4290
# ...

# %%
schools_2020_df = schools_2020_df[['School ID','Name of School','ZIP Code','Elementary, Middle, or High School','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2020_df = schools_2020_df[schools_2020_df['Elementary, Middle, or High School'] == "HS"]
schools_2020_df = schools_2020_df[['School ID','Name of School','ZIP Code','Graduation Rate %', 'Ward','Average Student Attendance']]
schools_2020_df
# Out:
#      School ID                                    Name of School  ZIP Code  \
# 8       609680     Walter Payton College Preparatory High School     60610
# 15      609722                 Manley Career Academy High School     60612
# 17      609749         Northside College Preparatory High School     60625
# 28      610244    Michele Clark Academic Prep Magnet High School     60644
# 30      610394                      Uplift Community High School     60640
# ..         ...                                               ...       ...
# 554     609753     Chicago High School for Agricultural Sciences     60655
# 559     609724                      Stephen T Mather High School     60659
# 560     610297          High School of Leadership at South Shore     60649
# 561     610506      TEAM Englewood Community Academy High School     60621
# 564     610384  Infinity Math Science and Technology High School     60623
#
#     Graduation Rate %  Ward  Average Student Attendance
# ...

# %%
csv_path_4 = os.path.join("crimes_2011_clean.csv")
crime_2011_df = pd.read_csv(csv_path_4, encoding="utf-8")
crime_2011_df.head()
# Out:
#    Unnamed: 0        Primary Type                          Description  \
# 0           0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1           3  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2           4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 3           6  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4           7  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#     Latitude  Longitude
# 0  41.747362 -87.708424
# 1  41.891766 -87.766554
# 2  41.895419 -87.766632
# 3  41.875944 -87.743451
# 4  41.987282 -87.787652

# %%
csv_path_5 = os.path.join("crimes_2015_clean.csv")
crime_2015_df = pd.read_csv(csv_path_5, encoding="utf-8")
crime_2015_df
# Out:
#         Unnamed: 0             Primary Type  \
# 0                0                  BATTERY
# 1                1                    THEFT
# 2                2                NARCOTICS
# 3                3                  ASSAULT
# 4                4                 BURGLARY
# ...            ...                      ...
# 257906      264610            OTHER OFFENSE
# 257907      264611                  BATTERY
# 257908      264612                  BATTERY
# 257909      264613                  BATTERY
# 257910      264616  CRIMINAL SEXUAL ASSAULT
#
#                                               Description   Latitude  \
# 0                                 DOMESTIC BATTERY SIMPLE  41.815117
# 1                                          POCKET-PICKING  41.895080
# 2                                   POSS: HEROIN(BRN/TAN)  41.937406
# 3                                                  SIMPLE  41.881903
# 4                                          FORCIBLE ENTRY  41.744379
# ...

# %%
csv_path_6 = os.path.join("crimes_2021_clean.csv")
crime_2021_df = pd.read_csv(csv_path_6, encoding="utf-8")
crime_2021_df
# Out:
#         Unnamed: 0                Primary Type  \
# 0                0          DECEPTIVE PRACTICE
# 1                3          DECEPTIVE PRACTICE
# 2                4          DECEPTIVE PRACTICE
# 3                6          DECEPTIVE PRACTICE
# 4                7          DECEPTIVE PRACTICE
# ...            ...                         ...
# 351308      351926                     BATTERY
# 351309      351929                     ASSAULT
# 351310      351930  OFFENSE INVOLVING CHILDREN
# 351311      351931               OTHER OFFENSE
# 351312      351932                     BATTERY
#
#                                               Description   Latitude  \
# 0                     FINANCIAL IDENTITY THEFT OVER $ 300  41.747362
# 1                     FINANCIAL IDENTITY THEFT OVER $ 300  41.891766
# 2                     FINANCIAL IDENTITY THEFT OVER $ 300  41.895419
# 3                     FINANCIAL IDENTITY THEFT OVER $ 300  41.875944
# ...

# %%
# # Not sure how to remove the additional column from these DFs. I tried deleting (del) and dropping (df.drop()), but then the column name "Unnamed: 0" is not registering.
# del crime_2021_df['Unnamed: 0']
# print(crime_2021_df)
# crime_2021_df.drop('Unnamed: 0', inplace=True, axis=1)
# print(crime_2021_df)

# %%
# Merging 2011 Schools DF with 2011 Crime DF. Not running, though due to KeyError.
twenty_eleven_df = pd.merge(schools_2011_df, crime_2011_df, on="Latitude", how="outer")
twenty_eleven_df.head()
