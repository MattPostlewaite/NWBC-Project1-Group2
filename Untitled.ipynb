# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "Crimes_-_2021 (1).csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

crimes_2021 = df[["Primary Type", "Description","Latitude","Longitude"]]
crimes_2021 = crimes_2021.dropna()
crimes_2021.to_csv('crimes_2021_real_clean.csv',encoding='utf-8')
crimes_2021
# Out:
#                       Primary Type  \
# 0                          BATTERY
# 1                            THEFT
# 2                          BATTERY
# 3                        NARCOTICS
# 4                         HOMICIDE
# ...                            ...
# 205442     CRIMINAL SEXUAL ASSAULT
# 205502                    BURGLARY
# 205503                     BATTERY
# 205507  OFFENSE INVOLVING CHILDREN
# 205560                     BATTERY
#
#                                               Description   Latitude  \
# 0                                 DOMESTIC BATTERY SIMPLE  41.766435
# 1                                          $500 AND UNDER  41.748474
# 2                                 DOMESTIC BATTERY SIMPLE  41.882224
# 3                                       POSSESS - COCAINE  41.790069
# 4                                     FIRST DEGREE MURDER  41.771062
# ...                                                   ...        ...
# 205442                                     NON-AGGRAVATED  41.776705
# 205502                                     FORCIBLE ENTRY  41.926829
# 205503  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...  41.799124
# 205507  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER  41.883146
# 205560  PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / ...  41.979006
#
#         Longitude
# 0      -87.635964
# 1      -87.630607
# 2      -87.766076
# 3      -87.654769
# 4      -87.586271
# ...           ...
# 205442 -87.687234
# 205502 -87.639162
# 205503 -87.587265
# 205507 -87.743759
# 205560 -87.906463
#
# [203090 rows x 4 columns]
